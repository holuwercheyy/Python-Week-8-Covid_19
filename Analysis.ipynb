# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
vaccination_counts = df[df['total_vaccinations'].notnull()] \
                        .groupby('location') \
                        .size() \
                        .sort_values(ascending=False)

print(vaccination_counts.head(10))
# Out:
# location
# High income            862
# Europe                 862
# World                  862
# European Union         860
# North America          851
# Asia                   849
# Upper middle income    849
# United States          843
# South America          840
# Italy                  836
# dtype: int64

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   14352
# location                                        0
# date                                            0
# total_cases                                 35741
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       292217
# excess_mortality_cumulative                292217
# excess_mortality                           292217
# excess_mortality_cumulative_per_million    292217
# Length: 67, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
filtered_df = df[df['continent'].isin(countries_of_interest)]

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = filtered_df[filtered_df['continent'] == country]
    plt.plot(country_data['date'], country_data['total_cases'], label=country)

plt.title('Total Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['total_deaths'])
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths Over Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = df_filtered[df_filtered['continent'] == country]
    plt.plot(country_data['date'], country_data['total_cases'], label=country)
    plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.title('Total COVID-19 Cases Over Time by Country')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = df_filtered[df_filtered['continent'] == country]
    plt.plot(country_data['date'], country_data['total_deaths'], label=country)
    plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths Over Time by Country')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
df['daily_new_cases'] = df.groupby('continent')['total_cases'].diff().fillna(0)

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = df[df['continent'] == country]
    plt.plot(country_data['date'], country_data['daily_new_cases'], label=country)

plt.title('Daily New Cases Comparison')
plt.xlabel('Date')
plt.ylabel('Daily New Cases')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Add a new column called 'death_rate' to the DataFrame
df['death_rate'] = df['total_deaths'] / df['total_cases']

# %%
df['death_rate'] = df['total_deaths'] / df['total_cases'].replace(0, pd.NA)

# %%
df['death_rate'] = df['death_rate'].fillna(0)

# %%
df_clean = df.dropna(subset=['death_rate'])

# %%
latest_data = df_clean.sort_values('date').groupby('location').last().reset_index()

# %%
top_death_rates = latest_data.sort_values('death_rate', ascending=False)

# %%
print(top_death_rates[['continent', 'total_cases', 'total_deaths', 'death_rate']].head(10))
# Out:
#          continent  total_cases  total_deaths  death_rate
# 252           Asia      11945.0        2159.0    0.180745
# 216         Africa      63922.0        5034.0    0.078752
# 220           Asia      57423.0        3163.0    0.055082
# 209         Africa      27334.0        1361.0    0.049791
# 177  South America    4492891.0      219866.0    0.048936
# 62          Africa     515913.0       24823.0    0.048115
# 142  North America    7553646.0      333596.0    0.044164
# 28          Europe     402636.0       16328.0    0.040553
# 0             Asia     211630.0        7884.0    0.037254
# 123         Africa       8090.0         294.0    0.036341

# %%
Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

for country in countries_of_interest:
    country_data = df[df['continent'] == country]

# %%
plt.figure(figsize=(16, 9))

for country in countries_of_interest:
    country_data = df_filtered[df_filtered['continent'] == country]

# %%
plt.plot(country_data['date'], country_data['total_cases'], label=f'{country} - Cases', linestyle='-')
plt.plot(country_data['date'], country_data['total_deaths'], label=f'{country} - Deaths', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Total COVID-19 Cases and Deaths Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['total_cases'] = pd.to_numeric(df['total_cases'], errors='coerce')

# %%
top_cases = df.groupby('continent')['total_cases'].max().sort_values(ascending=False).head(10)

# %%
print(top_cases)
# Out:
# continent
# North America    102873924.0
# Asia              99239252.0
# Europe            38791479.0
# South America     37319254.0
# Oceania           11153745.0
# Africa             4072533.0
# Name: total_cases, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
top_cases.plot(kind='bar', color='skyblue')

plt.title('Top 10 Countries by Total COVID-19 Cases')
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include='number')
corr_matrix = numeric_df.corr()

print(corr_matrix)
# Out:
#                                          total_cases  new_cases  \
# total_cases                                 1.000000   0.508620
# new_cases                                   0.508620   1.000000
# new_cases_smoothed                          0.532332   0.953175
# total_deaths                                0.933437   0.544850
# new_deaths                                  0.394494   0.495051
# ...                                              ...        ...
# excess_mortality_cumulative                 0.078600   0.052665
# excess_mortality                           -0.028044   0.065779
# excess_mortality_cumulative_per_million     0.183503   0.058858
# daily_new_cases                             0.032559   0.363248
# death_rate                                 -0.005573  -0.001956
#
#                                          new_cases_smoothed  total_deaths  \
# total_cases                                        0.532332      0.933437
# ...

# %%
numeric_df = df.select_dtypes(include='number')

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=0.5)

plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
Visualizing Vaccination Progress

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
df_filtered = df[(df['continent'].isin(countries_of_interest)) & (df['total_vaccinations'].notnull())]

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = df_filtered[df_filtered['continent'] == country]
    plt.plot(country_data['date'], country_data['total_vaccinations'], label=country)

plt.title('Cumulative COVID-19 Vaccinations Over Time')
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df_vacc = df[df['total_vaccinations_per_hundred'].notnull()]

# %%
latest_vacc = df_vacc.sort_values('date').groupby('continent').tail(1)

# %%
latest_vacc_sorted = latest_vacc.sort_values('total_vaccinations_per_hundred', ascending=False)

# %%
print(latest_vacc_sorted[['continent', 'total_vaccinations_per_hundred']].head(10))
# Out:
#             continent  total_vaccinations_per_hundred
# 11961   South America                          253.35
# 130250         Europe                          243.64
# 14353   North America                          164.01
# 121878           Asia                          155.70
# 275095         Africa                          107.22
# 209404        Oceania                            7.23

# %%
plt.figure(figsize=(12, 6))
top_countries = latest_vacc_sorted.head(10)

plt.bar(top_countries['continent'], top_countries['total_vaccinations_per_hundred'], color='green')

plt.title('Top 10 Countries by % of Population Vaccinated')
plt.xlabel('Country')
plt.ylabel('% Vaccinated (per hundred)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
Line Charts

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    country_data = df_filtered[df_filtered['continent'] == country]
    plt.plot(country_data['date'], country_data['total_vaccinations_per_hundred'], label=country)

plt.title('COVID-19: % of Population Vaccinated Over Time')
plt.xlabel('Date')
plt.ylabel('% Vaccinated (per hundred)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
Pie Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
latest_vacc = df_filtered.sort_values('date').groupby('location').tail(1)

print(latest_vacc[['continent', 'total_vaccinations_per_hundred']])
# Out:
#             continent  total_vaccinations_per_hundred
# 197510           Asia                             NaN
# 156153           Asia                          259.21
# 118290           Asia                          277.12
# 22725            Asia                             NaN
# 184859           Asia                             NaN
# ...               ...                             ...
# 218973           Asia                             NaN
# 10763   North America                             NaN
# 131446  North America                             NaN
# 121878           Asia                          155.70
# 300119           Asia                             NaN
#
# [106 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
countries_of_interest = ['North America','Asia', 'Italy', 'South America']
df_filtered = df[df['continent'].isin(countries_of_interest)]

# %%
df_filtered = df[(df['location'].isin(countries_of_interest)) & (df['total_vaccinations_per_hundred'].notnull())]

# %%
latest_vacc = df_filtered.sort_values('date').groupby('location').tail(1)

# %%
latest_vacc = latest_vacc.dropna(subset=['total_vaccinations_per_hundred'])

# %%
plt.figure(figsize=(8, 8))

plt.pie(latest_vacc['total_vaccinations_per_hundred'], 
        labels=latest_vacc['location'], 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=['skyblue', 'lightgreen', 'orange', 'pink'])

plt.title('Proportion of % Vaccinated Population (Latest Available Data)')
plt.axis('equal')
plt.show()
